# %%
from google.colab import drive
drive.mount('/content/drive/')

# from google.colab import files
# uploaded = files.upload()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pip install earthengine-api pystac
# Out:
# Requirement already satisfied: earthengine-api in /usr/local/lib/python3.12/dist-packages (1.5.24)
# Requirement already satisfied: pystac in /usr/local/lib/python3.12/dist-packages (1.14.2)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (from earthengine-api) (3.7.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /usr/local/lib/python3.12/dist-packages (from earthengine-api) (2.187.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from earthengine-api) (2.43.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from earthengine-api) (0.2.1)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from earthengine-api) (0.31.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from earthengine-api) (2.32.4)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from pystac) (2.9.0.post0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.12.1->earthengine-api) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.12.1->earthengine-api) (4.2.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.4.1->earthengine-api) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.4.1->earthengine-api) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.4.1->earthengine-api) (4.9.1)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.2.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7.0->pystac) (1.17.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api) (2.8.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api) (1.7.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->earthengine-api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->earthengine-api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->earthengine-api) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->earthengine-api) (2025.11.12)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.26.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api) (0.6.1)

# %%
import rasterio
import os
import re
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, Normalize
from shapely.geometry import mapping, box, Polygon
import requests
import xml.etree.ElementTree as ET
from io import BytesIO

import sys
sys.path.append('..')
#import constants
import csv

import pystac
from pystac.extensions.table import TableExtension
from urllib.parse import urlparse, parse_qs
from pystac import Asset, MediaType
from pystac.extensions.classification import ClassificationExtension, Classification
from pystac.extensions.raster import RasterExtension,RasterBand
from pystac.extensions.projection import ProjectionExtension
from pystac.catalog import CatalogType
import datetime
import ee
ee.Authenticate()
ee.Initialize(project='ee-corestackdev')

# %%
#STAC_SAVE_DIR = "/home/vishnu/STAC-spec-raster/STAC-spec/data/PANindia_stac_raster_test"
STAC_SAVE_DIR = "/content/drive/MyDrive/STAC_spec_PANIndia_test/PanIndiaCatalogs"

SUB_COLLECTIONS = {}

MAIN_COLLECTION_ID = "panindia-layers"

# %%
def load_sheet_df(sheet_id):

    url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&gid=0"
    df = pd.read_csv(url)
    df = df.dropna(how='all')

    cleaned_cols = []
    for col in df.columns:
        cleaned_col = re.sub(r'\s+', ' ', col.strip())
        cleaned_cols.append(cleaned_col)

    df.columns = cleaned_cols

    print(df.columns.tolist())

    REQUIRED_COLUMNS = ['collection_name', 'display_name', 'Layer Name', 'ee_layer_name', 'GEE asset link', 'Style file url']

    missing_cols = [col for col in REQUIRED_COLUMNS if col not in df.columns]
    if missing_cols:
        raise ValueError(
            f"Missing required columns in the sheet: {', '.join(missing_cols)}. "
            f"Google Sheet match the following list: {REQUIRED_COLUMNS}"
        )

    STYLE_URL_COLUMN = 'Style file url'
    LAYER_NAME_COLUMN = 'Layer Name'

    df = df.dropna(subset=[LAYER_NAME_COLUMN]).reset_index(drop=True)

    return df, STYLE_URL_COLUMN

# %%
sheet_id = '1ulwuZ0mEUpRYgchVlp9BLwTBs4eCp5PczR0zL79q1rA'
#sheet_id = "1rSg8Zm0RHQ7wgyVr7ZZoDj66CB88Om7gbXfqLhDK8HI"
#sheet_id='1sLskFtH-sbsWMEX7-oGlkwQCHu_OW7QaUdQSeRTGDIk'
df, STYLE_URL_COLUMN = load_sheet_df(sheet_id)
# Out:
# ['collection_name', 'display_name', 'Layer Name', 'ee_layer_name', 'GEE asset link', 'Style file url']

# %%
def read_raster_data(image_info, ee_image):
    band_info = image_info['bands'][0]

    crs = band_info.get('crs')
    transform = band_info.get('crs_transform', [30, 0, 0, 0, -30, 0])
    bands = len(image_info['bands'])

    if "dimensions" in band_info:
        width = band_info['dimensions'][0]
        height = band_info['dimensions'][1]
    else:
        print(f"'dimensions' missing for asset. Estimating from geometry & scale")
        try:
            scale_x = abs(transform[0])
            scale_y = abs(transform[4])
            region = ee.Image(ee_image).geometry().bounds().getInfo()
            coords = region["coordinates"][0]
            min_x, min_y = coords[0]
            max_x, max_y = coords[2]
            width = int((max_x - min_x) / scale_x)
            height = int((max_y - min_y) / scale_y)
        except Exception as e:
            raise RuntimeError(f"Could not infer dimensions: {e}")

    min_x = transform[2]
    max_y = transform[5]
    max_x = min_x + width * transform[0]
    min_y = max_y + height * transform[4]

    bbox = [min_x, min_y, max_x, max_y]
    footprint = Polygon([
        [min_x, min_y], [min_x, max_y],
        [max_x, max_y], [max_x, min_y],
        [min_x, min_y]
    ])

    try:
        gsd_meters = ee_image.projection().nominalScale().getInfo()
    except Exception as e:
        print(f"Could not get nominal scale in meters for CRS {crs}. Fallback to crs_transform. Error: {e}")
        gsd_meters = abs(transform[0])

    shape = (bands, height, width)
    data_type = band_info['data_type']['type']

    return (bbox, mapping(footprint), crs, gsd_meters, shape, data_type)

# %%
def normalize_key(text):
    text = text.lower()
    text = re.sub(r"[^a-z0-9]+", "-", text)
    text = re.sub(r"-+", "-", text)
    return text.strip("-")

# %%
def load_layer_descriptions(csv_path="/content/drive/MyDrive/layer_descriptions.csv"):
    desc_map = {}

    with open(csv_path, "r") as f:
        reader = csv.DictReader(f)
        for row in reader:
            norm_key = normalize_key(row["layer_name"])
            desc_map[norm_key] = row["layer_description"]

    return desc_map

LAYER_DESCRIPTIONS = load_layer_descriptions("/content/drive/MyDrive/layer_descriptions.csv")

# %%
def create_raster_item(id, bbox, footprint, crs, shape):

    description_key = normalize_key(id)
    item_description = LAYER_DESCRIPTIONS.get(description_key, id)

    raster_item = pystac.Item(
        id=id,
        geometry=footprint,
        bbox=bbox,
        datetime=datetime.datetime.now(datetime.timezone.utc),
        properties={"description": item_description},
    )

    proj_ext = ProjectionExtension.ext(raster_item, add_if_missing=True)
    proj_ext.epsg = 4326
    proj_ext.shape = [shape[1], shape[2]]

    return (raster_item, None)

# %%
def add_raster_data_asset(raster_item, url_string):
    raster_item.add_asset("data", Asset(
        href=url_string,
        roles=["data"],
        title="Asset Link"
    ))
    return raster_item

# %%
def add_raster_extension(raster_item, gsd_val, data_type_val):
    raster_ext = RasterExtension.ext(raster_item.assets["data"], add_if_missing=True)
    raster_band = RasterBand.create(
        data_type=data_type_val,
        spatial_resolution=gsd_val,
    )
    raster_ext.bands = [raster_band]

# %%
def parse_raster_style_file(style_file_url):

    try:
        response = requests.get(style_file_url)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        raise


    try:
        xml_string = response.content.decode('utf-8', errors='replace')
        style_content = BytesIO(xml_string.encode('utf-8'))
        tree = ET.parse(style_content)
    except ET.ParseError as e:
        try:
            print(f"Warning: Failed to parse XML with UTF-8 ({e}). Trying ISO-8859-1.")
            xml_string_alt = response.content.decode('iso-8859-1', errors='ignore')
            style_content = BytesIO(xml_string_alt.encode('utf-8'))
            tree = ET.parse(style_content)
        except ET.ParseError as e_final:
            raise e_final

    root = tree.getroot()
    classes = []

    for entry in root.findall(".//paletteEntry") + root.findall(".//item"):
        class_info = {}
        for attr_key, attr_value in entry.attrib.items():
            if attr_key == "value":
                try:
                    class_info[attr_key] = int(attr_value)
                except ValueError:
                    class_info[attr_key] = attr_value
            else:
                class_info[attr_key] = attr_value
        if class_info:
            classes.append(class_info)

    if not classes:
         raise ValueError(f"No classification data (paletteEntry or item tags) found in style file.")

    return classes

# %%
def add_classification_extension(raster_style_url, raster_item):

    style_info = parse_raster_style_file(style_file_url=raster_style_url)
    classification_ext = ClassificationExtension.ext(raster_item.assets["data"], add_if_missing=True)
    stac_classes = []

    for cls in style_info:
        color_hint = cls['color'].replace('#','') if cls.get('color') else None

        value = cls.get("value")
        if not isinstance(value, int):
             try:
                 value = int(float(str(value))) if value is not None else None
             except (TypeError, ValueError):
                 value = None

        if value is None:
             print(f"Classification skipped for an entry with invalid value.")
             continue

        stac_class_obj = Classification.create(
            value=value,
            name=cls.get("label") or f"Class {value}",
            description=cls.get("label"),
            color_hint=color_hint
        )
        stac_classes.append(stac_class_obj)

    if stac_classes:
        classification_ext.classes = stac_classes
    else:
        raster_item.assets["data"].properties.pop("classification:classes", None)


    return (raster_item,style_info)

# %%
def add_stylefile_asset(raster_item, style_file_url):
    raster_item.add_asset("style", Asset(
        href=style_file_url,
        media_type=MediaType.XML,
        roles=["metadata", "visualisation"],
        title="QGIS Style file"
    ))
    return raster_item

# %%
def generate_raster_stac(image_info, url_string, style_file_url, layer_name, gsd, data_type, bbox, footprint, crs, shape):

    stac_id = layer_name.replace(" ", "_").replace("/", "_").replace("-", "_").lower()


    raster_item, _ = create_raster_item(id=stac_id, bbox=bbox, footprint=footprint, crs=crs, shape=shape)

    raster_item.properties["title"] = layer_name

    raster_item = add_raster_data_asset(raster_item, url_string=url_string)

    add_raster_extension(raster_item, gsd_val=gsd, data_type_val=data_type)


    raster_item, style_info = add_classification_extension(raster_style_url=style_file_url,
                                                             raster_item=raster_item)

    raster_item = add_stylefile_asset(raster_item, style_file_url=style_file_url)

    return raster_item, style_info

# %%
def create_root_and_collection():

    root_collection_href = os.path.join(STAC_SAVE_DIR, "collection.json")


    extent = pystac.Extent(
    spatial=pystac.SpatialExtent(
        bboxes=[[68.0, 6.0, 97.0, 37.0]]
    ),
    temporal=pystac.TemporalExtent(
        intervals=[[
            datetime.datetime(2017, 7, 1),
            datetime.datetime(2024, 6, 30)
        ]]
    )
)

    root_collection = pystac.Collection(
        id='PanIndiaCatalogs',
        title='Pan India Spatio Temporal Asset Catalog',
        description='This spatio temporal asset catalog contains all data layers of CoRE Stack (https://core-stack.org/) generated at Pan India level.',
        extent=extent,
        license='CC-BY-4.0'
    )

    root_collection.set_self_href(root_collection_href)

    print(f"STAC Root Collection initialized at: {STAC_SAVE_DIR}")

    return root_collection, root_collection

# %%
def create_sub_collection(title, parent_collection):

    title_str = str(title) if title is not None else "unknown"
    collection_id = title.lower().replace(' ', '-').replace(':', '').replace('/', '-')

    description = f"STAC collection for {title_str} of India."

    if collection_id not in SUB_COLLECTIONS:
        print(f"Creating new Sub-Collection (Theme): {title} ---")

        sub_collection = pystac.Collection(
            id=collection_id,
            title=title,
            description=description,
            extent=parent_collection.extent,
            license=parent_collection.license,
            providers=parent_collection.providers
        )


        parent_collection.add_child(sub_collection)
        SUB_COLLECTIONS[collection_id] = sub_collection

    return SUB_COLLECTIONS[collection_id]

# %%
def parse_asset_id(url_string, row_index):
    try:
        parsed_url = urlparse(url_string)
        query_params = parse_qs(parsed_url.query)
        return query_params['asset'][0]
    except Exception as e:
        print(f"Skipping row {row_index}: Could not parse asset ID from URL: {url_string}. Error: {e}")
        return None

# %%
def load_gee_image(asset_id, mosaic_if_collection=True):

    try:
        asset_metadata = ee.data.getAsset(asset_id)
        asset_type = asset_metadata.get('type')

        if asset_type == 'IMAGE':
            print("Confirmed asset type: ee.Image.")
            return ee.Image(asset_id)

        elif asset_type == 'IMAGE_COLLECTION':
            print("Confirmed asset type: ee.ImageCollection.")
            collection = ee.ImageCollection(asset_id)

            if mosaic_if_collection:

                first_img = ee.Image(collection.first())
                proj = first_img.projection()
                scale = proj.nominalScale()
                crs = proj.crs()

                print(f"Using projection from first image: {crs}, scale: {scale.getInfo()} m")


                mosaicked = collection.mosaic().reproject(crs=crs, scale=scale)
                return mosaicked
            else:
                return collection

        elif asset_type == 'TABLE':
            print("Confirmed asset type: ee.FeatureCollection.")
            return ee.FeatureCollection(asset_id)

        else:
            print(f"Unsupported asset type: {asset_type}. Skipping.")
            return None

    except Exception as e:
        print(f"Failed to load asset {asset_id}: {e}")
        return None

# %%
def add_raster_extension_to_asset(item, asset_key, gsd_val, data_type_val):
    if asset_key in item.assets:
        raster_ext = RasterExtension.ext(item.assets[asset_key], add_if_missing=True)
        raster_band = RasterBand.create(
            data_type=data_type_val,
            spatial_resolution=gsd_val,
        )
        raster_ext.bands = [raster_band]

def add_projection_extension_to_asset(item, asset_key, crs, shape):

    if asset_key in item.assets:
        proj_ext = ProjectionExtension.ext(item.assets[asset_key], add_if_missing=True)


        if isinstance(crs, str) and "EPSG:" in crs:
            try:
                proj_ext.epsg = int(crs.split(":")[-1])
            except:
                proj_ext.wkt2 = crs


        if shape and len(shape) >= 2:

            proj_ext.shape = [shape[1], shape[2]] if len(shape) == 3 else [shape[0], shape[1]]

def add_classification_extension_to_asset(item, asset_key, style_url):

    if asset_key not in item.assets or not style_url:
        return

    try:
        style_info = parse_raster_style_file(style_file_url=style_url)
        classification_ext = ClassificationExtension.ext(item.assets[asset_key], add_if_missing=True)
        stac_classes = []

        for cls in style_info:
            color_hint = cls['color'].replace('#','') if cls.get('color') else None
            value = cls.get("value")


            try:
                if value is not None:
                    value = int(float(str(value)))
                else:
                    continue
            except (ValueError, TypeError):
                continue

            stac_class_obj = Classification.create(
                value=value,
                name=cls.get("label") or f"Class {value}",
                description=cls.get("label"),
                color_hint=color_hint
            )
            stac_classes.append(stac_class_obj)

        if stac_classes:
            classification_ext.classes = stac_classes
    except Exception as e:
        print(f"Warning: Failed to add classification to {item.id}: {e}")

# %%
def process_layer(index, row, style_col_name, target_collection):

    original_layer_name = str(row['Layer Name']).strip()
    ee_layer_name = str(row['ee_layer_name']).strip()
    asset_link = str(row['GEE asset link']).strip()
    base_display_name = str(row['display_name']).strip() if not pd.isna(row['display_name']) else original_layer_name
    style_url = str(row[style_col_name]).strip() if not pd.isna(row[style_col_name]) and str(row[style_col_name]).lower() != 'nan' else None


    targeted_layers = [
        'tree_canopy_cover_density_raster',
        'tree_canopy_height_raster',
        'land_use_land_cover_raster',
        'nrsc_land_use_land_cover_raster'
    ]

    display_name = base_display_name
    if any(target.lower() in original_layer_name.lower() for target in targeted_layers):
        year_match = re.search(r'(\d{4}\s*[\-\_]\s*\d{4}|\d{4})', ee_layer_name)
        if year_match:
            extracted_year = year_match.group(0).strip()

            display_name = f"{base_display_name}: {extracted_year}"


    def normalize_key_local(s):
        return str(s).lower().replace(" ", "").replace("-", "").replace("_", "").strip()

    description_key = normalize_key_local(original_layer_name)
    item_description = original_layer_name
    for k, v in LAYER_DESCRIPTIONS.items():
        if normalize_key_local(k) == description_key:
            item_description = v
            break


    asset_id = parse_asset_id(asset_link, index)
    ee_image = load_gee_image(asset_id)
    bbox = [-180.0, -90.0, 180.0, 90.0]
    footprint, crs, gsd, shape, data_type = None, None, None, None, None

    if ee_image:
        try:
            image_info = ee_image.getInfo()
            bbox, footprint, crs, gsd, shape, data_type = read_raster_data(image_info, ee_image)
        except Exception as e:
            print(f"Warning: Metadata fetch failed for {asset_id}: {e}")


    unique_name_part = re.sub(r'[\s\.\-]+', '_', ee_layer_name.lower()).strip('_')
    item_id = f"{original_layer_name}_{unique_name_part}".lower()

    item = pystac.Item(
        id=item_id,
        geometry=footprint,
        bbox=bbox,
        datetime=datetime.datetime.now(datetime.timezone.utc),
        properties={
            'title': display_name,
            'description': item_description
        }
    )


    gee_asset = pystac.Asset(
        href=asset_link,
        media_type=pystac.MediaType.GEOTIFF,
        roles=['data'],
        title="Asset Link"
    )
    item.add_asset(key='gee_asset', asset=gee_asset)
    asset_obj = item.assets['gee_asset']


    if gsd and data_type:
        raster_ext = RasterExtension.ext(asset_obj, add_if_missing=True)
        raster_ext.bands = [RasterBand.create(data_type=data_type, spatial_resolution=gsd)]


    if crs and shape:

        proj_ext = ProjectionExtension.ext(item, add_if_missing=True)

        if "EPSG:" in str(crs):
            proj_ext.epsg = int(str(crs).split(":")[-1])
        else:
            proj_ext.wkt2 = str(crs)


        if len(shape) == 3:
            proj_ext.shape = [shape[1], shape[2]]
        else:
            proj_ext.shape = [shape[0], shape[1]]


    if style_url:
        try:
            add_classification_to_asset(asset_obj, style_url)
            item.add_asset(key='qgis_style', asset=pystac.Asset(
                href=style_url, media_type=pystac.MediaType.XML, roles=['metadata', 'style'], title='QGIS Style file'
            ))
        except: pass

    target_collection.add_item(item)
    return 1

# %%
def add_classification_to_asset(asset_obj, style_url):
    style_info = parse_raster_style_file(style_file_url=style_url)
    class_ext = ClassificationExtension.ext(asset_obj, add_if_missing=True)

    stac_classes = []
    for cls in style_info:
        try:
            val = int(float(str(cls.get("value"))))
            stac_classes.append(Classification.create(
                value=val,
                name=cls.get("label") or f"Class {val}",
                description=cls.get("label"),
                color_hint=cls.get('color', '').replace('#','')
            ))
        except:
            continue

    if stac_classes:
        class_ext.classes = stac_classes

# %%
def save_catalog(catalog, count):
    if count > 0:

        catalog.normalize_hrefs(STAC_SAVE_DIR)
        catalog.save(catalog_type=pystac.CatalogType.SELF_CONTAINED)
        print(f"Catalog saved to {STAC_SAVE_DIR}")
        print(f"Structure created")
    else:
        print("No items were generated.")

# %%
def run_stac_generation(df, root_collection, STYLE_URL_COLUMN):
    generated_items_count = 0

    collection_groups = df.groupby('collection_name')

    for collection_name, group_df in collection_groups:
        collection_title = collection_name.strip()

        collection_id = collection_title.lower().replace(' ', '_')


        target_collection = root_collection.get_child(collection_id)

        if not target_collection:
            print(f"Creating Sub-Collection Folder: {collection_id} ---")
            target_collection = pystac.Collection(
                id=collection_id,
                title=collection_title,
                description=f"STAC collection for {collection_title} of India..",
                extent=root_collection.extent,
                license='CC-BY-4.0'
            )

            root_collection.add_child(target_collection)


        for index, row in group_df.iterrows():
            layer_name = row['Layer Name'].strip()


            if target_collection.get_item(layer_name):
                print(f"Skipping: {layer_name} (Already exists)")
                continue

            item_count = process_layer(index, row, STYLE_URL_COLUMN, target_collection)
            generated_items_count += item_count


            if generated_items_count % 5 == 0 and generated_items_count > 0:
                root_collection.normalize_hrefs(STAC_SAVE_DIR)
                root_collection.save(catalog_type=pystac.CatalogType.SELF_CONTAINED)


    root_collection.normalize_hrefs(STAC_SAVE_DIR)
    root_collection.save(catalog_type=pystac.CatalogType.SELF_CONTAINED)

    print(f"SUCCESS: Total {generated_items_count} new items processed.")
    print(f"Final structure available in: {STAC_SAVE_DIR}")

# %%
df, STYLE_URL_COLUMN = load_sheet_df(sheet_id)

root_collection, collection_ptr = create_root_and_collection()

run_stac_generation(df, root_collection, STYLE_URL_COLUMN)
# Out:
# ['collection_name', 'display_name', 'Layer Name', 'ee_layer_name', 'GEE asset link', 'Style file url']
# STAC Root Collection initialized at: /content/drive/MyDrive/STAC_spec_PANIndia_test/PanIndiaCatalogs
# Creating Sub-Collection Folder: drainage_layers ---
# Confirmed asset type: ee.Image.
# Warning: Failed to parse XML with UTF-8 (not well-formed (invalid token): line 25, column 75). Trying ISO-8859-1.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Creating Sub-Collection Folder: geological_and_geohydrological_layers ---
# Confirmed asset type: ee.Image.
# Creating Sub-Collection Folder: land_use_land_cover ---
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Creating Sub-Collection Folder: open_ecosystems_and_degradation ---
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Confirmed asset type: ee.Image.
# Creating Sub-Collection Folder: terrain ---
# Confirmed asset type: ee.Image.
# Warning: Failed to parse XML with UTF-8 (not well-formed (invalid token): line 25, column 75). Trying ISO-8859-1.
# Failed to load asset projects/corestack-datasets/assets/datasets/terrain/pan_india_terrain_raster_famdem: Asset 'projects/corestack-datasets/assets/datasets/terrain/pan_india_terrain_raster_famdem' does not exist or doesn't allow this operation.
# Warning: Failed to parse XML with UTF-8 (not well-formed (invalid token): line 25, column 75). Trying ISO-8859-1.
# Confirmed asset type: ee.Image.
# Creating Sub-Collection Folder: tree_characteristics ---
# Confirmed asset type: ee.ImageCollection.
# Using projection from first image: ee.String({
#   "functionInvocationValue": {
#     "functionName": "Projection.crs",
#     "arguments": {
#       "projection": {
#         "functionInvocationValue": {
#           "functionName": "Image.projection",
#           "arguments": {
#             "image": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.first",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "ImageCollection.load",
#                       "arguments": {
#                         "id": {
#                           "constantValue": "projects/corestack-datasets/assets/datasets/tree_health/modal_ccd_2017"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }), scale: 25 m
# 'dimensions' missing for asset. Estimating from geometry & scale
# Confirmed asset type: ee.ImageCollection.
# Using projection from first image: ee.String({
#   "functionInvocationValue": {
#     "functionName": "Projection.crs",
#     "arguments": {
#       "projection": {
#         "functionInvocationValue": {
#           "functionName": "Image.projection",
#           "arguments": {
#             "image": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.first",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "ImageCollection.load",
#                       "arguments": {
#                         "id": {
#                           "constantValue": "projects/corestack-datasets/assets/datasets/tree_health/modal_ccd_2018"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }), scale: 25 m
# 'dimensions' missing for asset. Estimating from geometry & scale
# Confirmed asset type: ee.ImageCollection.
# Using projection from first image: ee.String({
#   "functionInvocationValue": {
#     "functionName": "Projection.crs",
#     "arguments": {
#       "projection": {
#         "functionInvocationValue": {
#           "functionName": "Image.projection",
#           "arguments": {
#             "image": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.first",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "ImageCollection.load",
#                       "arguments": {
#                         "id": {
#                           "constantValue": "projects/corestack-datasets/assets/datasets/tree_health/modal_ccd_2019"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }), scale: 25 m
# 'dimensions' missing for asset. Estimating from geometry & scale
# Confirmed asset type: ee.ImageCollection.
# Using projection from first image: ee.String({
#   "functionInvocationValue": {
#     "functionName": "Projection.crs",
#     "arguments": {
#       "projection": {
#         "functionInvocationValue": {
#           "functionName": "Image.projection",
#           "arguments": {
#             "image": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.first",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "ImageCollection.load",
#                       "arguments": {
#                         "id": {
#                           "constantValue": "projects/corestack-datasets/assets/datasets/tree_health/modal_ccd_2020"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }), scale: 25 m
# 'dimensions' missing for asset. Estimating from geometry & scale
# Confirmed asset type: ee.ImageCollection.
# Using projection from first image: ee.String({
#   "functionInvocationValue": {
#     "functionName": "Projection.crs",
#     "arguments": {
#       "projection": {
#         "functionInvocationValue": {
#           "functionName": "Image.projection",
#           "arguments": {
#             "image": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.first",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "ImageCollection.load",
#                       "arguments": {
#                         "id": {
#                           "constantValue": "projects/corestack-datasets/assets/datasets/tree_health/modal_ccd_2021"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }), scale: 25 m
# 'dimensions' missing for asset. Estimating from geometry & scale
# Confirmed asset type: ee.ImageCollection.
# Using projection from first image: ee.String({
#   "functionInvocationValue": {
#     "functionName": "Projection.crs",
#     "arguments": {
#       "projection": {
#         "functionInvocationValue": {
#           "functionName": "Image.projection",
#           "arguments": {
#             "image": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.first",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "ImageCollection.load",
#                       "arguments": {
#                         "id": {
#                           "constantValue": "projects/corestack-datasets/assets/datasets/tree_health/modal_ch_2017"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }), scale: 25 m
# 'dimensions' missing for asset. Estimating from geometry & scale
# Confirmed asset type: ee.ImageCollection.
# Using projection from first image: ee.String({
#   "functionInvocationValue": {
#     "functionName": "Projection.crs",
#     "arguments": {
#       "projection": {
#         "functionInvocationValue": {
#           "functionName": "Image.projection",
#           "arguments": {
#             "image": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.first",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "ImageCollection.load",
#                       "arguments": {
#                         "id": {
#                           "constantValue": "projects/corestack-datasets/assets/datasets/tree_health/modal_ch_2018"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }), scale: 25 m
# 'dimensions' missing for asset. Estimating from geometry & scale
# Confirmed asset type: ee.ImageCollection.
# Using projection from first image: ee.String({
#   "functionInvocationValue": {
#     "functionName": "Projection.crs",
#     "arguments": {
#       "projection": {
#         "functionInvocationValue": {
#           "functionName": "Image.projection",
#           "arguments": {
#             "image": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.first",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "ImageCollection.load",
#                       "arguments": {
#                         "id": {
#                           "constantValue": "projects/corestack-datasets/assets/datasets/tree_health/modal_ch_2019"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }), scale: 25 m
# 'dimensions' missing for asset. Estimating from geometry & scale
# Confirmed asset type: ee.ImageCollection.
# Using projection from first image: ee.String({
#   "functionInvocationValue": {
#     "functionName": "Projection.crs",
#     "arguments": {
#       "projection": {
#         "functionInvocationValue": {
#           "functionName": "Image.projection",
#           "arguments": {
#             "image": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.first",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "ImageCollection.load",
#                       "arguments": {
#                         "id": {
#                           "constantValue": "projects/corestack-datasets/assets/datasets/tree_health/modal_ch_2020"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }), scale: 25 m
# 'dimensions' missing for asset. Estimating from geometry & scale
# Confirmed asset type: ee.ImageCollection.
# Using projection from first image: ee.String({
#   "functionInvocationValue": {
#     "functionName": "Projection.crs",
#     "arguments": {
#       "projection": {
#         "functionInvocationValue": {
#           "functionName": "Image.projection",
#           "arguments": {
#             "image": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.first",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "ImageCollection.load",
#                       "arguments": {
#                         "id": {
#                           "constantValue": "projects/corestack-datasets/assets/datasets/tree_health/modal_ch_2021"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }), scale: 25 m
# 'dimensions' missing for asset. Estimating from geometry & scale
# Creating Sub-Collection Folder: tree_change_analysis ---
# Confirmed asset type: ee.ImageCollection.
# Using projection from first image: ee.String({
#   "functionInvocationValue": {
#     "functionName": "Projection.crs",
#     "arguments": {
#       "projection": {
#         "functionInvocationValue": {
#           "functionName": "Image.projection",
#           "arguments": {
#             "image": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.first",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "ImageCollection.load",
#                       "arguments": {
#                         "id": {
#                           "constantValue": "projects/corestack-datasets/assets/datasets/tree_health/overall_change_2017_2021"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }), scale: 25 m
# 'dimensions' missing for asset. Estimating from geometry & scale
# Confirmed asset type: ee.ImageCollection.
# Using projection from first image: ee.String({
#   "functionInvocationValue": {
#     "functionName": "Projection.crs",
#     "arguments": {
#       "projection": {
#         "functionInvocationValue": {
#           "functionName": "Image.projection",
#           "arguments": {
#             "image": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.first",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "ImageCollection.load",
#                       "arguments": {
#                         "id": {
#                           "constantValue": "projects/corestack-datasets/assets/datasets/tree_health/final_ltp_stp_change_2017_2021"
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }), scale: 25 m
# 'dimensions' missing for asset. Estimating from geometry & scale
# Creating Sub-Collection Folder: wri_restoration_opportunities_atlas ---
# Confirmed asset type: ee.Image.
#
# SUCCESS: Total 45 new items processed.
# Final structure available in: /content/drive/MyDrive/STAC_spec_PANIndia_test/PanIndiaCatalogs
